# %%
import importlib
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt

from sccoda.util import comp_ana as mod
from sccoda.util import cell_composition_data as dat
from sccoda.util import data_visualization as viz

import sccoda.datasets as scd
# Out:
# 2024-12-19 21:32:07.845302: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_csv('metadata.csv')
df['samples'] = df['day']+'_'+df['condition']

# %%
pivot_df = df.pivot_table(index='samples', columns='celltypes', aggfunc='size', fill_value=0)
pivot_df['days'] = pivot_df.index.map(lambda x: x.split('_')[0])
pivot_df['condition'] = pivot_df.index.map(lambda x: x.split('_')[1])

# %%
row1, row2 = 0, 2  # Specify the indices of rows to exchange

# Swap rows and their indices
row1_data = pivot_df.iloc[row1].copy()
row2_data = pivot_df.iloc[row2].copy()

pivot_df.iloc[row1] = row2_data
pivot_df.iloc[row2] = row1_data

pivot_df.index.values[row1], pivot_df.index.values[row2] = pivot_df.index.values[row2], pivot_df.index.values[row1]

# %%
pivot_df['condition'] = pivot_df['condition'].map(lambda x: 'A_ctr' if x == 'ctr' else x)

# %%
data_all = dat.from_pandas(pivot_df, covariate_columns=['days',"condition"])
print(data_all)
# Out:
# AnnData object with n_obs × n_vars = 9 × 15
#     obs: 'days', 'condition'

# %%
data_all[data_all.obs['days'].isin(['D35','D56'])].X
# Out:
# ArrayView([[    0,     0,     0,   164,   308,  1088,   430,  2462,
#                 0,  3341,     0,  2166,     0,     0,   404],
#            [    0,     0,     0,   142,   179,   432,  2733,  1241,
#                 0,  2018,     0,  1565,     0,   691,   785],
#            [    0,     0,     0,   176,   844,  2972,  5275,  6727,
#                 0,  8250,     0,  3569,     0,     0,  1734],
#            [    0,  1019,  3662,     0,   196,   770,   308,     0,
#                 0,  1693,     0,   639,   423,     0,  1400],
#            [    0,   307,  3727,     0,   128,   924,  2312,     0,
#                 0,  1819,     0,   570,   513,   116,   696],
#            [    0,  1924, 11715,     0,   191,  1420,  6316,     0,
#                 0,  4354,     0,  1091,  1130,     0,  2301]])

# %%
import re
delimiters = r'[/ ]'
re.split(delimiters, 'a/b c')
# Out:
# ['a', 'b', 'c']

# %%
for ct in data_all.var_names:
    viz.boxplots(data_all, feature_name="days", cell_types=[ct], args_boxplot={"linewidth":0.4, "widths":0.2}),# figsize=(15, 7))
    file_name = '_'.join(re.split(delimiters, ct))
    plt.savefig(f'./celltype_proportion_days/{file_name}.pdf')
    #plt.show()
    
viz.boxplots(data_all, feature_name="days",figsize=(15, 6), args_boxplot={"linewidth":0.4, "widths":0.2})
plt.savefig(f'./celltype_proportion_days/all_celltypes.pdf')

# %%
for ct in data_all.var_names:
    viz.boxplots(data_all, feature_name="condition", cell_types=[ct], level_order=['FGF', 'ctr', 'BMP'], args_boxplot={"linewidth":0.4, "widths":0.2}),# figsize=(15, 7))
    file_name = '_'.join(re.split(delimiters, ct))
    plt.savefig(f'./celltype_proportion_conditions/{file_name}.pdf')
    #plt.show()

viz.boxplots(data_all, feature_name="condition",figsize=(15, 6), level_order=['FGF', 'ctr', 'BMP'], args_boxplot={"linewidth":0.4, "widths":0.2})
plt.savefig(f'./celltype_proportion_conditions/all_celltypes.pdf')

# %%
day_pairs = [['D35','D56'], ['D56', 'D97'], ['D35', 'D97']]
condition_pairs = [['ctr','FGF'], ['ctr','BMP'], ['BMP','FGF']]

sim_results = {}
sim_results['days'] = {}
sim_results['conditions'] = {}

for day_pair in day_pairs:
    model_day = mod.CompositionalAnalysis(data_all[data_all.obs['days'].isin(day_pair),:], formula="days")
    print(1)
    # Run MCMC
    sim_result = model_day.sample_hmc()
    print(2)
    sim_results['days']['_'.join(day_pair)] = sim_result

for cond_pair in condition_pairs:
    model_cond = mod.CompositionalAnalysis(data_all[data_all.obs['condition'].isin(cond_pair),:], formula="condition")
    print(1)
    # Run MCMC
    sim_result = model_cond.sample_hmc()
    print(2)
    sim_results['conditions']['_'.join(cond_pair)] = sim_result
# Out:
# Automatic reference selection! Reference cell type set to DMT
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734680175.721054   28719 service.cc:145] XLA service 0x7fd4c34235a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734680175.721111   28719 service.cc:153]   StreamExecutor device (0): Host, Default Version
# 2024-12-19 21:36:15.721404: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#   0%|          | 0/20000 [00:00<?, ?it/s]2024-12-19 21:36:15.865054: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1734680176.810616   28719 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100%|██████████| 20000/20000 [01:21<00:00, 245.62it/s]
# MCMC sampling finished. (105.283 sec)
# Acceptance rate: 73.0%
# 2
# Automatic reference selection! Reference cell type set to cycling cells
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 1
# 100%|██████████| 20000/20000 [01:20<00:00, 247.21it/s]
# MCMC sampling finished. (103.642 sec)
# Acceptance rate: 74.1%
# 2
# Automatic reference selection! Reference cell type set to IP
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 1
# 100%|██████████| 20000/20000 [01:21<00:00, 245.01it/s]
# MCMC sampling finished. (104.488 sec)
# Acceptance rate: 68.2%
# 2
# Automatic reference selection! Reference cell type set to IP
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 1
# 100%|██████████| 20000/20000 [01:21<00:00, 246.06it/s]
# MCMC sampling finished. (104.098 sec)
# Acceptance rate: 60.3%
# 2
# Automatic reference selection! Reference cell type set to IP
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 1
# 100%|██████████| 20000/20000 [01:30<00:00, 220.94it/s]
# WARNING:tensorflow:5 out of the last 5 calls to <function CompositionalModel.sampling.<locals>.sample_mcmc at 0x15770caf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MCMC sampling finished. (117.524 sec)
# Acceptance rate: 49.6%
# 2
# Automatic reference selection! Reference cell type set to IP
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 1
# 100%|██████████| 20000/20000 [01:25<00:00, 233.73it/s]
# WARNING:tensorflow:6 out of the last 6 calls to <function CompositionalModel.sampling.<locals>.sample_mcmc at 0x157b03400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MCMC sampling finished. (110.084 sec)
# Acceptance rate: 57.2%
# 2

# %%
import os
for fdr in [2, 4, 6, 8]:
    for key in sim_results:
        for pair in sim_results[key]:
            sim_result = sim_results[key][pair]
            sim_result.set_fdr(est_fdr=0.1 * fdr)
            file_dir = f'/Users/albert/Desktop/Projects/Prompt_Optimization/sccoda_results_0_{fdr}/{pair}'
            os.makedirs(file_dir)
            sim_result.credible_effects().to_csv(file_dir + '/credible_effects.csv', index=True)
            sim_result.intercept_df.to_csv(file_dir + '/sccoda_intercept.csv', index=True)
            sim_result.effect_df.to_csv(file_dir +'/sccoda_effect.csv', index=True)

# %%
sim_results.credible_effects()
# Out:
# Covariate    Cell Type
# days[T.D56]  CPEC                                  False
#              CR                                     True
#              DLN                                    True
#              DMD                                    True
#              DMT                                   False
#              IP                                    False
#              L/CGE like interneuron/progenitors    False
#              PP/CR                                  True
#              ULN                                   False
#              aRG                                   False
#              aRG/oRG                               False
#              cycling cells                         False
#              newborn neurons                        True
#              oRG-like cells                        False
#              stressed cells                        False
# Name: Final Parameter, dtype: bool

# %%
sim_results.set_fdr(est_fdr=0.4)

# %%
sim_results.intercept_df.to_csv('sccoda_intercept.csv', index=True)

# %%
sim_results.effect_df.to_csv('sccoda_effect.csv', index=True)

# %%
sim_results.effect_df
# Out:
#                                                      Final Parameter  HDI 3%  \
# Covariate        Cell Type
# days[T.D56]      CPEC                                      -0.122212  -1.399
#                  CR                                         3.701424   2.657
#                  DLN                                        5.454001   4.394
#                  DMD                                       -1.754336  -3.030
#                  DMT                                       -0.123991  -0.922
#                  IP                                         0.000000   0.000
#                  L/CGE like interneuron/progenitors         0.391101  -0.050
#                  PP/CR                                     -4.441215  -5.510
#                  ULN                                        0.103620  -1.254
#                  aRG                                        0.000000  -0.456
#                  aRG/oRG                                   -0.067090  -1.468
#                  cycling cells                             -0.561206  -1.167
#                  newborn neurons                            3.467989   2.048
#                  oRG-like cells                            -0.063104  -1.691
#                  stressed cells                             0.931440   0.198
# days[T.D97]      CPEC                                       0.523623  -0.556
#                  CR                                         2.956247   1.758
#                  DLN                                        5.379873   4.355
#                  DMD                                       -1.576016  -2.995
#                  DMT                                       -2.463865  -3.551
#                  IP                                         0.000000   0.000
#                  L/CGE like interneuron/progenitors         0.000000  -0.647
#                  PP/CR                                     -4.455656  -5.525
#                  ULN                                        5.745698   4.813
#                  aRG                                       -4.810607  -5.956
#                  aRG/oRG                                    4.298858   3.330
#                  cycling cells                             -0.361663  -1.017
#                  newborn neurons                            3.122455   1.757
#                  oRG-like cells                            -0.846342  -2.720
#                  stressed cells                             0.000000  -0.911
# condition[T.BMP] CPEC                                       0.329393  -0.524
#                  CR                                         0.300902  -0.335
#                  DLN                                        0.000000  -0.147
#                  DMD                                        0.198014  -0.744
#                  DMT                                        0.095172  -0.783
#                  IP                                         0.000000   0.000
#                  L/CGE like interneuron/progenitors        -1.758598  -2.329
#                  PP/CR                                     -0.041704  -0.591
#                  ULN                                       -0.121285  -0.504
#                  aRG                                       -0.002013  -0.340
#                  aRG/oRG                                    0.044469  -0.434
#                  cycling cells                              0.000000  -0.372
#                  newborn neurons                            0.000000  -0.627
#                  oRG-like cells                            -0.321984  -1.988
#                  stressed cells                             0.000000  -0.746
# condition[T.FGF] CPEC                                       0.070005  -0.380
#                  CR                                        -0.375627  -1.012
#                  DLN                                       -0.013940  -0.285
#                  DMD                                        0.008086  -0.581
#                  DMT                                       -0.080760  -0.561
#                  IP                                         0.000000   0.000
#                  L/CGE like interneuron/progenitors         0.124985  -0.150
#                  PP/CR                                     -0.280289  -0.744
#                  ULN                                       -0.170159  -0.535
#                  aRG                                       -0.029742  -0.272
#                  aRG/oRG                                    0.030671  -0.410
#                  cycling cells                              0.126195  -0.233
#                  newborn neurons                           -0.032545  -0.517
#                  oRG-like cells                             0.638447  -0.261
#                  stressed cells                             0.142742  -0.272
#
#                                                      HDI 97%     SD  \
# Covariate        Cell Type
# days[T.D56]      CPEC                                  1.014  0.317
#                  CR                                    4.813  0.590
#                  DLN                                   6.456  0.533
#                  DMD                                   0.066  0.953
#                  DMT                                   0.832  0.279
#                  IP                                    0.000  0.000
#                  L/CGE like interneuron/progenitors    0.811  0.248
#                  PP/CR                                -3.309  0.617
#                  ULN                                   1.225  0.377
#                  aRG                                   0.386  0.079
#                  aRG/oRG                               1.434  0.422
#                  cycling cells                         0.046  0.384
#                  newborn neurons                       4.779  0.709
#                  oRG-like cells                        1.120  0.398
#                  stressed cells                        1.528  0.459
# days[T.D97]      CPEC                                  1.944  0.502
#                  CR                                    3.994  0.634
#                  DLN                                   6.444  0.539
#                  DMD                                   0.039  0.998
#                  DMT                                  -0.997  0.680
#                  IP                                    0.000  0.000
#                  L/CGE like interneuron/progenitors    0.316  0.094
#                  PP/CR                                -3.134  0.634
#                  ULN                                   6.703  0.515
#                  aRG                                  -3.680  0.602
#                  aRG/oRG                               5.189  0.515
#                  cycling cells                         0.073  0.253
#                  newborn neurons                       4.532  0.746
#                  oRG-like cells                        0.680  0.720
#                  stressed cells                        0.356  0.155
# condition[T.BMP] CPEC                                  1.345  0.408
#                  CR                                    0.897  0.261
#                  DLN                                   0.460  0.096
#                  DMD                                   1.094  0.379
#                  DMT                                   0.758  0.268
#                  IP                                    0.000  0.000
#                  L/CGE like interneuron/progenitors   -1.077  0.340
#                  PP/CR                                 0.566  0.170
#                  ULN                                   0.197  0.121
#                  aRG                                   0.394  0.105
#                  aRG/oRG                               0.738  0.170
#                  cycling cells                         0.464  0.109
#                  newborn neurons                       0.537  0.157
#                  oRG-like cells                        0.540  0.472
#                  stressed cells                        0.391  0.153
# condition[T.FGF] CPEC                                  0.808  0.255
#                  CR                                    0.146  0.338
#                  DLN                                   0.182  0.069
#                  DMD                                   0.687  0.207
#                  DMT                                   0.363  0.174
#                  IP                                    0.000  0.000
#                  L/CGE like interneuron/progenitors    0.450  0.127
#                  PP/CR                                 0.121  0.228
#                  ULN                                   0.060  0.157
#                  aRG                                   0.243  0.101
#                  aRG/oRG                               0.371  0.154
#                  cycling cells                         0.470  0.158
#                  newborn neurons                       0.384  0.140
#                  oRG-like cells                        2.429  0.747
#                  stressed cells                        0.600  0.181
#
#                                                      Inclusion probability  \
# Covariate        Cell Type
# days[T.D56]      CPEC                                             0.286733
#                  CR                                               1.000000
#                  DLN                                              1.000000
#                  DMD                                              0.882333
#                  DMT                                              0.298933
#                  IP                                               0.000000
#                  L/CGE like interneuron/progenitors               0.403733
#                  PP/CR                                            1.000000
#                  ULN                                              0.321667
#                  aRG                                              0.165867
#                  aRG/oRG                                          0.336200
#                  cycling cells                                    0.505133
#                  newborn neurons                                  1.000000
#                  oRG-like cells                                   0.303667
#                  stressed cells                                   0.850867
# days[T.D97]      CPEC                                             0.353867
#                  CR                                               1.000000
#                  DLN                                              1.000000
#                  DMD                                              0.718533
#                  DMT                                              1.000000
#                  IP                                               0.000000
#                  L/CGE like interneuron/progenitors               0.175933
#                  PP/CR                                            1.000000
#                  ULN                                              1.000000
#                  aRG                                              1.000000
#                  aRG/oRG                                          1.000000
#                  cycling cells                                    0.332067
#                  newborn neurons                                  1.000000
#                  oRG-like cells                                   0.391733
#                  stressed cells                                   0.187800
# condition[T.BMP] CPEC                                             0.483667
#                  CR                                               0.420467
#                  DLN                                              0.244667
#                  DMD                                              0.497133
#                  DMT                                              0.425133
#                  IP                                               0.000000
#                  L/CGE like interneuron/progenitors               1.000000
#                  PP/CR                                            0.309733
#                  ULN                                              0.275400
#                  aRG                                              0.321000
#                  aRG/oRG                                          0.301800
#                  cycling cells                                    0.243400
#                  newborn neurons                                  0.258200
#                  oRG-like cells                                   0.466800
#                  stressed cells                                   0.268467
# condition[T.FGF] CPEC                                             0.511933
#                  CR                                               0.689200
#                  DLN                                              0.295867
#                  DMD                                              0.479000
#                  DMT                                              0.442600
#                  IP                                               0.000000
#                  L/CGE like interneuron/progenitors               0.432733
#                  PP/CR                                            0.510000
#                  ULN                                              0.557133
#                  aRG                                              0.525600
#                  aRG/oRG                                          0.502533
#                  cycling cells                                    0.449200
#                  newborn neurons                                  0.328667
#                  oRG-like cells                                   0.741467
#                  stressed cells                                   0.489667
#
#                                                      Expected Sample  \
# Covariate        Cell Type
# days[T.D56]      CPEC                                      18.757938
#                  CR                                       943.175482
#                  DLN                                     5652.367888
#                  DMD                                       16.452755
#                  DMT                                      216.770067
#                  IP                                      1092.068196
#                  L/CGE like interneuron/progenitors      3759.078775
#                  PP/CR                                     22.865133
#                  ULN                                       23.746825
#                  aRG                                     2598.861140
#                  aRG/oRG                                   19.801121
#                  cycling cells                            685.825296
#                  newborn neurons                          670.362017
#                  oRG-like cells                            28.695057
#                  stressed cells                          1454.283422
# days[T.D97]      CPEC                                      31.398313
#                  CR                                       392.830569
#                  DLN                                     4605.489587
#                  DMD                                       17.255237
#                  DMT                                       18.325004
#                  IP                                       958.271880
#                  L/CGE like interneuron/progenitors      2230.835678
#                  PP/CR                                     19.776124
#                  ULN                                     5877.163820
#                  aRG                                       18.569570
#                  aRG/oRG                                 1367.841343
#                  cycling cells                            734.704393
#                  newborn neurons                          416.375145
#                  oRG-like cells                            11.505088
#                  stressed cells                           502.769361
# condition[T.BMP] CPEC                                      60.959650
#                  CR                                        65.086760
#                  DLN                                       50.039822
#                  DMD                                      239.806792
#                  DMT                                      558.353047
#                  IP                                      2259.319924
#                  L/CGE like interneuron/progenitors       906.164637
#                  PP/CR                                   3851.105336
#                  ULN                                       39.233615
#                  aRG                                     5365.826391
#                  aRG/oRG                                   45.800185
#                  cycling cells                           2486.966884
#                  newborn neurons                           43.242298
#                  oRG-like cells                            45.825237
#                  stressed cells                          1185.380535
# condition[T.FGF] CPEC                                      37.283914
#                  CR                                        26.230683
#                  DLN                                       39.119350
#                  DMD                                      157.219538
#                  DMT                                      371.220772
#                  IP                                      1791.049410
#                  L/CGE like interneuron/progenitors      4724.618311
#                  PP/CR                                   2404.909433
#                  ULN                                       29.618468
#                  aRG                                     4137.366750
#                  aRG/oRG                                   35.810036
#                  cycling cells                           2236.689316
#                  newborn neurons                           33.182153
#                  oRG-like cells                            94.917090
#                  stressed cells                          1083.875887
#
#                                                      log2-fold change
# Covariate        Cell Type
# days[T.D56]      CPEC                                       -0.895169
#                  CR                                          4.621170
#                  DLN                                         7.149605
#                  DMD                                        -3.249827
#                  DMT                                        -0.897737
#                  IP                                         -0.718855
#                  L/CGE like interneuron/progenitors         -0.154617
#                  PP/CR                                      -7.126175
#                  ULN                                        -0.569363
#                  aRG                                        -0.718855
#                  aRG/oRG                                    -0.815646
#                  cycling cells                              -1.528504
#                  newborn neurons                             4.284396
#                  oRG-like cells                             -0.809895
#                  stressed cells                              0.624928
# days[T.D97]      CPEC                                       -0.151984
#                  CR                                          3.357551
#                  DLN                                         6.854104
#                  DMD                                        -3.181122
#                  DMT                                        -4.462017
#                  IP                                         -0.907411
#                  L/CGE like interneuron/progenitors         -0.907411
#                  PP/CR                                      -7.335565
#                  ULN                                         7.381879
#                  aRG                                        -7.847651
#                  aRG/oRG                                     5.294529
#                  cycling cells                              -1.429181
#                  newborn neurons                             3.597339
#                  oRG-like cells                             -2.128425
#                  stressed cells                             -0.907411
# condition[T.BMP] CPEC                                        0.805184
#                  CR                                          0.764080
#                  DLN                                         0.329970
#                  DMD                                         0.615645
#                  DMT                                         0.467275
#                  IP                                          0.329970
#                  L/CGE like interneuron/progenitors         -2.207151
#                  PP/CR                                       0.269805
#                  ULN                                         0.154993
#                  aRG                                         0.327065
#                  aRG/oRG                                     0.394125
#                  cycling cells                               0.329970
#                  newborn neurons                             0.329970
#                  oRG-like cells                             -0.134555
#                  stressed cells                              0.329970
# condition[T.FGF] CPEC                                        0.095883
#                  CR                                         -0.547029
#                  DLN                                        -0.025224
#                  DMD                                         0.006553
#                  DMT                                        -0.121625
#                  IP                                         -0.005113
#                  L/CGE like interneuron/progenitors          0.175202
#                  PP/CR                                      -0.409485
#                  ULN                                        -0.250601
#                  aRG                                        -0.048022
#                  aRG/oRG                                     0.039136
#                  cycling cells                               0.176948
#                  newborn neurons                            -0.052066
#                  oRG-like cells                              0.915971
#                  stressed cells                              0.200819

# %% [markdown]
# In "credible_effect.csv", the final parameter column means whether the covariate has a credible effect of change on celltype proportion for each celltype. For example in D35_D56, D35 is the baseline and D56 is a covariate.
#
# In "sccoda_effect.csv", this is a quantitative version of effect. The "final parameter" column corresponds to the true/false in the credible effects, where 0 means false and positive means true. The log-2 fold change column shows a similar pattern.
#
# In "sccoda_intercept.csv", the "final parameter" column shows how the cell types are distributed without any active covariates. This file is not needed in comparing between different covariates.
#
# You can check out https://sccoda.readthedocs.io/en/latest/getting_started.html for more interpretations.
